# %%
import nltk

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet

# %%
from nltk.corpus import movie_reviews
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import stopwords

# %%
negative_reviews = movie_reviews.fileids('neg')

# %%
all_words = movie_reviews.words()
len(all_words)
# Out:
# 1583820

# %%
def word_features(w):
    useful_words = [w.lower() for w in words if w.lower() not in stopwords.words('english')]
    my_dict = dict([(word, True) for word in useful_words])
    
    return my_dict

# %%
neg_reviews = []
for fileid in movie_reviews.fileids('neg'):
    words = movie_reviews.words(fileid)
    #print(words)
    neg_reviews.append((word_features(words), "negative"))

# %%
pos_reviews = []
for fileid in movie_reviews.fileids('pos'):
    words = movie_reviews.words(fileid)
    #print(words)
    pos_reviews.append((word_features(words), "positive"))

# %%
reviews = []
for (words, sentiment) in neg_reviews + pos_reviews:
    words_filtered = [e.lower() for e in words.keys() if len(e) >= 3]
    reviews.append((words_filtered, sentiment))
# for (words, sentiment) in neg_reviews:
#     print(words.keys())
#     print()
reviews[:5]
# Out:
# [(['plot',
#    'two',
#    'teen',
#    'couples',
#    'church',
#    'party',
#    'drink',
#    'drive',
#    'get',
#    'accident',
#    'one',
#    'guys',
#    'dies',
#    'girlfriend',
#    'continues',
#    'see',
#    'life',
#    'nightmares',
#    'deal',
#    'watch',
#    'movie',
#    'sorta',
#    'find',
#    'critique',
#    'mind',
#    'fuck',
#    'generation',
#    'touches',
#    'cool',
#    'idea',
#    'presents',
#    'bad',
#    'package',
#    'makes',
#    'review',
#    'even',
#    'harder',
#    'write',
#    'since',
#    'generally',
#    'applaud',
#    'films',
#    'attempt',
#    'break',
#    'mold',
#    'mess',
#    'head',
#    'lost',
#    'highway',
#    'memento',
#    'good',
#    'ways',
#    'making',
#    'types',
#    'folks',
#    'snag',
#    'correctly',
#    'seem',
#    'taken',
#    'pretty',
#    'neat',
#    'concept',
#    'executed',
#    'terribly',
#    'problems',
#    'well',
#    'main',
#    'problem',
# ...

# %%
classifier = nltk.NaiveBayesClassifier.train(neg_reviews+pos_reviews)

# %%
test_data = "This was awesome movie. I am feeling good"
words = [word for word in word_tokenize(test_data.lower()) if len(word) >= 3 ]
words
test_data_features = (word in words for word in reviews)
test_data_features

# print (classifier.classify(test_data_features))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-261364e61102> in <module>()
#       5 # test_data_features
#       6
# ----> 7 print (classifier.classify(test_data_features))
#
# I:\anaconda\Anaconda3\lib\site-packages\nltk\classify\naivebayes.py in classify(self, featureset)
#      86
#      87     def classify(self, featureset):
# ---> 88         return self.prob_classify(featureset).max()
#      89
#      90     def prob_classify(self, featureset):
#
# I:\anaconda\Anaconda3\lib\site-packages\nltk\classify\naivebayes.py in prob_classify(self, featureset)
#      92         # Otherwise, we'll just assign a probability of 0 to
#      93         # everything.
# ---> 94         featureset = featureset.copy()
#      95         for fname in list(featureset.keys()):
#      96             for label in self._labels:
#
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
  
# Step 1 – Training data
train = [("Great place to be when you are in Bangalore.", "pos"),
  ("The place was being renovated when I visited so the seating was limited.", "neg"),
  ("Loved the ambience, loved the food", "pos"),
  ("The food is delicious but not over the top.", "neg"),
  ("Service - Little slow, probably because too many people.", "neg"),
  ("The place is not easy to locate", "neg"),
  ("Mushroom fried rice was spicy", "pos"),
]
  
# Step 2
dictionary = set(word.lower() for passage in train for word in word_tokenize(passage[0]))
  
# Step 3
t = [({word: (word in word_tokenize(x[0])) for word in dictionary}, x[1]) for x in train]
  
# Step 4 – the classifier is trained with sample data
classifier = nltk.NaiveBayesClassifier.train(neg_reviews+pos_reviews)
  
test_data = "Manchurian was not good"
test_data_features = {word.lower(): (word in word_tokenize(test_data.lower())) for word in dictionary}
  
print (classifier.classify(test_data_features))
# Out:
# positive

# %%
pos_reviewss = []
for fileid in movie_reviews.fileids('pos')[:5]:
    words = movie_reviews.words(fileid)
    #print(words)
    pos_reviewss.append((word_features(words), "positive"))

# %%
pos_reviewss
# Out:
# [({'"': True,
#    "'": True,
#    '(': True,
#    ')': True,
#    ',': True,
#    '-': True,
#    '.': True,
#    '/': True,
#    '00': True,
#    '102': True,
#    '12': True,
#    '1888': True,
#    '2': True,
#    '30': True,
#    '500': True,
#    '80s': True,
#    ':': True,
#    '?': True,
#    'abberline': True,
#    'ably': True,
#    'absinthe': True,
#    'accent': True,
#    'acting': True,
#    'acts': True,
#    'actually': True,
#    'adapted': True,
#    'alan': True,
#    'albert': True,
#    'allen': True,
#    'almost': True,
#    'amounts': True,
#    'another': True,
#    'anyone': True,
#    'anything': True,
#    'apes': True,
#    'appearance': True,
#    'arriving': True,
#    'arthouse': True,
#    'attempt': True,
#    'back': True,
#    'bad': True,
#    'batman': True,
#    'befriends': True,
#    'behind': True,
#    'better': True,
#    'big': True,
#    'black': True,
#    'blame': True,
#    'bleak': True,
#    'blindly': True,
#    'block': True,
# ...
